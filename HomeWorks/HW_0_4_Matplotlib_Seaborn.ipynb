# %% [markdown]
# # Курс по нейронным сетям
#
# # Введение в Python
#
# # Домашнее задание 4: Визуализация данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Light
# ### *Часть 1: Matplotlib*

# %% [markdown]
# ### Задача 1
#
# Используя библиотеку Matplotlib, постройте график экспоненты. Подпишите оси. Дайте название графику.

# %%
x = np.linspace(0,15,100)
y = np.exp(x)
plt.plot(x,y)
plt.title('Exp')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Задача 2
#
# Используя библиотеку Matplotlib, постройте графики функций $y = x^3$ и $y = x^2$ на одном графике.
#
# * Дайте название графику
# * Дайте названия осям
# * Присвойте лейблы и выведите легенду
# * Графики функций должены быть отрисованы пунктирными линиями (любыми из доступных на ваш вкус)

# %%
x = np.linspace(0,10,100)
y1 = x**3
y2 = x*x
plt.plot(x, y1, label='x^3')
plt.plot(x, y2, label='x^2')
plt.title('Task 2')
plt.xlabel('x')
plt.ylabel('y,z')
plt.legend(loc='upper right')
plt.show;

# %% [markdown]
# ### Задача 3
#
# Выведите на экран картинку ascent, которая подгружается кодом ниже

# %%
from scipy import misc
img = misc.ascent()
img.shape
# Out:
# (512, 512)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Задача 4
#
# Выведите на экран картинку выше в серых цветах (grayscale)

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# ### *Часть 2: Seaborn*

# %% [markdown]
# ### Задача 5
#
# Подгрузите данные datatraining.txt при помощи соответствующей функции библиотеки Pandas. Преобразуйте индекс в datetime index, удалите столбец с датой. Постройте график всех парных взаимосвязей с разметкой цвета в соответствии с метками классов (столбец Occupancy)
#
# P.S. используйте функцию sns.pairplot c параметром hue

# %%
import seaborn as sns
from google.colab import files

files.upload()
# !ls
# Out:
#      <input type="file" id="files-0ac9b662-fb31-4411-9bf9-435ba258f9dd" name="files[]" multiple disabled />
#      <output id="result-0ac9b662-fb31-4411-9bf9-435ba258f9dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datatraining_lesson_seaborn.txt to datatraining_lesson_seaborn.txt
# datatraining_lesson_seaborn.txt  sample_data

# %%
d5 = pd.read_csv('datatraining_lesson_seaborn.txt')
d5.index = pd.to_datetime(d5['date'])
d5.drop(['date'], axis='columns', inplace=True)
d5.head()
# Out:
#                      Temperature  Humidity  ...  HumidityRatio  Occupancy
# date                                        ...
# 2015-02-04 17:51:00        23.18   27.2720  ...       0.004793          1
# 2015-02-04 17:51:59        23.15   27.2675  ...       0.004783          1
# 2015-02-04 17:53:00        23.15   27.2450  ...       0.004779          1
# 2015-02-04 17:54:00        23.15   27.2000  ...       0.004772          1
# 2015-02-04 17:55:00        23.10   27.2000  ...       0.004757          1
#
# [5 rows x 6 columns]

# %%
sns.pairplot(d5, hue='Occupancy')
plt.show()

# %% [markdown]
# ### Задача 6
#
# Постройте boxplot всех признаков.
#
# P.S. график должен быть читаемым, т.е.
# * отрегулируйте размер графика
# * предварительно "отскейлите" все *числовые* признаки, т.е. приведите к стандартному нормальному распределению при помощи функции ниже

# %%
def scale(df):
    return (df - df.mean()) / df.std()

plt.figure(figsize=(12,6))
d6 = scale(d5)
sns.boxplot(data = d6, orient='h')
plt.title('Task 6')
plt.show()
print(d6.shape)
# Out:
# (8143, 6)

# %% [markdown]
# ### Задача 7
#
# Постройте violinplot всех признаков
#
# P.S. Предварительно приведите их к стандартному нормальному распределению как мы делали в предыдущей задаче

# %%
plt.figure(figsize=(17,9))
plt.title('Task 7')
sns.violinplot(data=scale(d5), orient='h')
plt.show()

# %% [markdown]
# ### Задача 8
#
# Нарисуйте heatmap матрицы корреляций используя функцию sns.heatmap(). Отрегулируйте масштаб, подберите подходящую палитру

# %%
plt.figure(figsize=(17,17))
sns.heatmap(d5.corr(), cmap=sns.color_palette("RdBu_r", 1000), vmin=-1, center=0.15, annot=True)
plt.show()

# %% [markdown]
# ## Pro
#
# ### *Часть 1: Matplotlib*

# %% [markdown]
# ### Задача 1
#
# Используя библиотеку Matplotlib, для датасета "Ирисы", который подгружается кодом ниже, нарисуйте точечную диаграмму (scatter plot) всех четырех признаков. Каждый признак должен быть нарисован на отдельном графике. Используйте для этого subplot формата 2 на 2. Графики должны быть читаемыми, т.е. отрегулируйте размер subplot'ов. Добовьте названия признаков к каждому графику в качестве имени графика. Используйте метки классов (y) в качестве цветовой разметки. Добавьте расшифровку цветов, соответствующих меткам классов, в качестве лейблов.
#
# P.S. используйте функцию plt.scatter(x, y, color)

# %%
from sklearn import datasets
data = datasets.load_iris(return_X_y=False)
X = data.data
y = data.target
names = data.target_names

# %%
# it is from stackoverflow, https://ru.stackoverflow.com/questions/1121789/%d0%98%d1%81%d0%bf%d0%be%d0%bb%d1%8c%d0%b7%d0%be%d0%b2%d0%b0%d0%bd%d0%b8%d0%b5-%d0%bc%d0%b5%d1%82%d0%be%d0%ba-%d0%ba%d0%bb%d0%b0%d1%81%d1%81%d0%b0-%d0%b2-%d0%ba%d0%b0%d1%87%d0%b5%d1%81%d1%82%d0%b2%d0%b5-%d1%86%d0%b2%d0%b5%d1%82%d0%be%d0%b2%d0%be%d0%b9-%d1%80%d0%b0%d0%b7%d0%bc%d0%b5%d1%82%d0%ba%d0%b8
# but I really understand it, every row, cool! Thank you, MaxU!
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

colors = list(mcolors.TABLEAU_COLORS.values())

f,axes = plt.subplots(2,2, sharex=False, sharey=False, figsize=(20,10))
for i,ax in enumerate(axes.flatten()):
  for target in np.unique(data.target):
    mask = (y == target)
    ax.scatter(x=np.arange(len(y[mask])), y=X[mask, i], c=colors[target])
  ax.set_title(data.feature_names[i])
  ax.legend(data.target_names)

# %% [markdown]
# ### Задача 2
#
# Используя библиотеку Matplotlib, постройте гистограмму для первого признака в датасете выше следующим образом:
# * на одном графике должно быть три гистаграммы, по одной на каждый класс
# * для этого используйте методологии подвыборки массива с условием
# * кол-во бинов должно определятся автоматически (режим "auto")
# * гистограмма должна быть читаемой, т.е. добавьте подписи, лейблы, названия и т.д.

# %%
colors = list(mcolors.TABLEAU_COLORS.values())
f, axes = plt.subplots(1,3, sharex=False, sharey=False, figsize=(15,5))
f.suptitle(data.feature_names[0], y = 1.2, fontsize = 30)
for i, ax in enumerate(axes.flatten()):
  #for target in np.unique(data.target):
    mask = (y == i)
    ax.hist(X[mask,0], bins='auto', color=colors[i])
    ax.set_title(data.target_names[i])
    ax.set_xlabel(data.feature_names[0])
    ax.set_ylabel('count')

# %% [markdown]
# ### Задача 3
#
# Используя библиотеку Matplotlib, посчитайте матрицу корреляции между признаками и нарисуйте ее как heatmap. Подберите подходящую по смысле цветовую гамму. Добавьте названия признаков в качестве тиков по осям. Добавьте отрисовку цветовой шкалы.

# %%
from sklearn.datasets import load_iris
import pandas as pd

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import seaborn as sns
import pandas as pd
#data1 = pd.DataFrame(data=data.data)
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap=sns.color_palette("BuGn_r"), annot=True)
plt.show()

# %% [markdown]
# ### *Часть 2: Seaborn*

# %% [markdown]
# ### Задача 4
#
# Для датасета Occupancy (datatraining.txt) постройте ... текст был утерян, потому что авторы немножечко мудаки, хотя вообще курс хорош.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
Occupancy = pd.read_csv('datatraining_lesson_seaborn.txt')

# %%
Occupancy.index=pd.to_datetime(Occupancy.date)
Occupancy = Occupancy.resample('H').mean()
Occupancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 137 entries, 2015-02-04 17:00:00 to 2015-02-10 09:00:00
# Freq: H
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    137 non-null    float64
#  1   Humidity       137 non-null    float64
#  2   Light          137 non-null    float64
#  3   CO2            137 non-null    float64
#  4   HumidityRatio  137 non-null    float64
#  5   Occupancy      137 non-null    float64
# dtypes: float64(6)
# memory usage: 7.5 KB

# %%
Occupancy.Temperature = Occupancy.Temperature.round()
Occupancy
# Out:
#                      Temperature   Humidity  ...  HumidityRatio  Occupancy
# date                                         ...
# 2015-02-04 17:00:00         23.0  27.220500  ...       0.004768   1.000000
# 2015-02-04 18:00:00         23.0  27.388278  ...       0.004654   0.116667
# 2015-02-04 19:00:00         22.0  27.181093  ...       0.004462   0.000000
# 2015-02-04 20:00:00         22.0  26.755593  ...       0.004288   0.000000
# 2015-02-04 21:00:00         21.0  25.911694  ...       0.004102   0.000000
# ...                          ...        ...  ...            ...        ...
# 2015-02-10 05:00:00         20.0  33.031271  ...       0.004821   0.000000
# 2015-02-10 06:00:00         20.0  33.095125  ...       0.004833   0.000000
# 2015-02-10 07:00:00         20.0  33.035533  ...       0.004868   0.000000
# 2015-02-10 08:00:00         20.0  33.319294  ...       0.004929   0.338983
# 2015-02-10 09:00:00         21.0  35.231483  ...       0.005388   1.000000
#
# ...

# %%
ax = sns.countplot(x="Temperature", data=Occupancy)

# %% [markdown]
# ### Задача 5
#
# Сделайте resample данных по получасовому интервалу с использованием усреднения для всех признаков. Обратите внимание, что столбец с метками класса Occupancy вместо усреднения нужно взять "как есть", т.е. resample c методом "asfreq" или "bfill".
#
# Постройте sns.jointplot между признаками Light и CO2

# %%
Occupancy.index=pd.to_datetime(Occupancy.date)
funcs = dict(Temperature='mean', Humidity='mean', Light='mean', CO2='mean', HumidityRatio='mean', Occupancy='bfill')
Occupancy = Occupancy.resample('30min').agg(funcs).dropna()
Occupancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 181 entries, 2015-02-04 18:00:00 to 2015-02-10 09:00:00
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    181 non-null    float64
#  1   Humidity       181 non-null    float64
#  2   Light          181 non-null    float64
#  3   CO2            181 non-null    float64
#  4   HumidityRatio  181 non-null    float64
#  5   Occupancy      181 non-null    float64
# dtypes: float64(6)
# memory usage: 9.9 KB

# %%
import matplotlib.pyplot as plt
sns.jointplot(data=Occupancy, x=Occupancy.iloc[:,2], y=Occupancy.iloc[:,3])
plt.show()

# %% [markdown]
# ### Задача 6
#
# Постройте boxplot всех признаков с разбивкой по Occupancy. Для правильной отрисовки необходимо:
#     * создать новый екстовый столбец с расшифровкой столбца Occupancy, например, если 0 - то 'No', если 1 - то 'Yes
#     * передать этот столбец в качестве соответствующего параметра боксплоту
#     * для каждого признака нужен отдельный график

# %%
Occupancy1 = pd.read_csv('datatraining_lesson_seaborn.txt')
Occupancy1.index=pd.to_datetime(Occupancy1.date)
Occupancy1.drop(columns=['date'],inplace=True)
Occupancy1.Occupancy = Occupancy1.Occupancy.replace({0: 'No',1:'Yes'})

# %%
Occupancy1
# Out:
#                      Temperature  Humidity  ...  HumidityRatio  Occupancy
# date                                        ...
# 2015-02-04 17:51:00        23.18   27.2720  ...       0.004793        Yes
# 2015-02-04 17:51:59        23.15   27.2675  ...       0.004783        Yes
# 2015-02-04 17:53:00        23.15   27.2450  ...       0.004779        Yes
# 2015-02-04 17:54:00        23.15   27.2000  ...       0.004772        Yes
# 2015-02-04 17:55:00        23.10   27.2000  ...       0.004757        Yes
# ...                          ...       ...  ...            ...        ...
# 2015-02-10 09:29:00        21.05   36.0975  ...       0.005579        Yes
# 2015-02-10 09:29:59        21.05   35.9950  ...       0.005563        Yes
# 2015-02-10 09:30:59        21.10   36.0950  ...       0.005596        Yes
# 2015-02-10 09:32:00        21.10   36.2600  ...       0.005621        Yes
# 2015-02-10 09:33:00        21.10   36.2000  ...       0.005612        Yes
#
# [8143 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df.drop('target', axis=1), x='sepal length (cm)', y='target_names', hue='target_names')
plt.show()

# %%
for col in Occupancy1.columns[:-1]:
  plt.figure(figsize=(18,4))
  sns.boxplot(data=Occupancy1, x=col, y = 'Occupancy', hue='Occupancy')
  plt.show()
